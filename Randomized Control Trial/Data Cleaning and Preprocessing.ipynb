# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams
from scipy import stats
import seaborn as sns
from datetime import datetime
import random
import math
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
# Reduce decimal points to 2
pd.options.display.float_format = '{:,.2f}'.format

import statistics 
from statistics import mode 
from collections import Counter

import os
import glob
#import psycopg2
import getopt
import sys
import math
import decimal
import copy
import csv
import progressbar
import time
#from toolkit import Date
from datetime import timedelta
import networkx as nx
#from network_viz import toGraph

import json 
import itertools

#from network_viz import output_Network_Viz
#from network_viz import get_Network_Viz_Monthly

# %%
start_date = datetime.strptime('2020-01-25', '%Y-%m-%d')
end_date = datetime.strptime('2020-09-10', '%Y-%m-%d')
#end_date = datetime.strptime(datetime.today().strftime("%Y-%m-%d"), "%Y-%m-%d")

# %%
def sample_from(dict_input):
    return {k: dict_input[k] for k in list(dict_input)[:2]}

# %% [markdown]
# ### Read userData csv and save as dict

# %%
userData_raw = pd.read_csv('/Users/rebeccamqamelo/Desktop/Capstone/users_all_pub_Nov2020.csv', header=0, index_col=None)

# %%
# Apply correct datetime format
userData_raw['start'] = pd.to_datetime(userData_raw['start'], format='%Y-%m-%d').dt.floor('d')
userData_raw.sort_values(by='start', inplace=True)

# Fix messy genders
nans = userData_raw.index[userData_raw['gender'].isnull()].tolist()
userData_raw.loc[(userData_raw.index.isin(nans)) & (userData_raw.held_roles != 'ADMIN'), 'gender'] = 'unknown gender'
userData_raw.loc[(userData_raw.index.isin(nans)) & (userData_raw.held_roles == 'ADMIN'), 'gender'] = 'system'
userData_raw.gender = userData_raw.gender.str.lower()
userData_raw.gender = userData_raw.gender.replace('male ', 'male')

userData_raw.to_csv('/Users/rebeccamqamelo/Desktop/Capstone/userData_raw_sorted.csv')

# %%
reader = csv.DictReader(open('/Users/rebeccamqamelo/Desktop/Capstone/userData_raw_sorted.csv'))

userData_dict = {}
for row in reader:
    key = row.pop('xDAI_blockchain_address')
    if key in userData_dict:
        # implement your duplicate row handling here
        pass
    userData_dict[key] = row

# %%
# Save the dict for faster processing next time

"""
w = csv.writer(open("/Users/rebeccamqamelo/Desktop/Capstone/userData_dict.csv", "w"))
for key, val in userData_dict.items():
    w.writerow([key, val])
    
# Now read in the dict – PROCESS BROKEN (returns Dict as string and only returns firtst entry)
uD_dict_test = dict(csv.DictReader(open("/Users/rebeccamqamelo/Desktop/Capstone/userData_dict.csv", "r")))
#ordered_dict_from_csv = list(dict_reader)[0]
#dict_from_csv = dict(ordered_dict_from_csv)

"""

# %%
# Check that the dictionary is in the correct format, with wallet addresses as keys
sample_from(userData_dict)
# Out:
# {'0xBAB77A20a757e8438DfaBF01D5F36DD12d862B31': OrderedDict([('', '40302'),
#               ('id', '4'),
#               ('start', '2018-10-21'),
#               ('label', '4'),
#               ('gender', 'male'),
#               ('location', 'Kilifi,Kilifi,Coastal Kenya'),
#               ('lat', '39.85'),
#               ('lon', '-3.6333'),
#               ('held_roles', 'BENEFICIARY'),
#               ('business_type', 'Farming/Labour'),
#               ('bal', '2448.88600155909'),
#               ('ovol_in', '86049.7860015591'),
#               ('ovol_out', '44075.0'),
#               ('otxns_in', '13'),
#               ('otxns_out', '2'),
#               ('ounique_in', '2'),
#               ('ounique_out', '1'),
#               ('svol_in', '22744.1'),
#               ('svol_out', '62270.0'),
#               ('stxns_in', '32'),
#               ('stxns_out', '32'),
#               ('sunique_in', '23'),
#               ('sunique_out', '20')]),
#  '0xC1697C1326fD192438515fE2F7E4cCb0C705C5d2': OrderedDict([('', '14176'),
#               ('id', '3'),
#               ('start', '2018-10-21'),
#               ('label', '3'),
#               ('gender', 'male'),
#               ('location', 'Kilifi,Kilifi,Coastal Kenya'),
#               ('lat', '39.85'),
#               ('lon', '-3.6333'),
#               ('held_roles', 'BENEFICIARY'),
#               ('business_type', 'Farming/Labour'),
#               ('bal', '0.660892016264'),
#               ('ovol_in', '9103.66089201626'),
#               ('ovol_out', '96.0'),
#               ('otxns_in', '2'),
#               ('otxns_out', '3'),
#               ('ounique_in', '2'),
#               ('ounique_out', '1'),
#               ('svol_in', '0.0'),
#               ('svol_out', '9007.0'),
#               ('stxns_in', '0'),
#               ('stxns_out', '1'),
#               ('sunique_in', '0'),
#               ('sunique_out', '1')])}

# %% [markdown]
# ### Read txnData csv and save as dict

# %%
txnData_raw = pd.read_csv('/Users/rebeccamqamelo/Desktop/Capstone/tx_all_pub_Nov2020.csv', header=0, index_col=None)
# Out:
# /Users/rebeccamqamelo/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Apply correct datetime format
txnData_raw['timeset'] = pd.to_datetime(txnData_raw['timeset'], format='%Y-%m-%d').dt.floor('d')
txnData_raw.sort_values(by='timeset', inplace=True)

# Fix messy genders
s_nans = txnData_raw.index[txnData_raw['s_gender'].isnull()].tolist()
txnData_raw.loc[(txnData_raw.index.isin(nans)), 's_gender'] = 'unknown gender'
txnData_raw.loc[(txnData_raw.s_business_type == 'System'), 's_gender'] = 'system'
txnData_raw.s_gender = txnData_raw.s_gender.str.lower()
txnData_raw.s_gender = txnData_raw.s_gender.replace('male ', 'male')

t_nans = txnData_raw.index[txnData_raw['t_gender'].isnull()].tolist()
txnData_raw.loc[(txnData_raw.index.isin(nans)), 't_gender'] = 'unknown gender'
txnData_raw.loc[(txnData_raw.t_business_type == 'System'), 't_gender'] = 'system'
txnData_raw.t_gender = txnData_raw.t_gender.str.lower()
txnData_raw.t_gender = txnData_raw.t_gender.replace('male ', 'male')

txnData_raw.to_csv('/Users/rebeccamqamelo/Desktop/Capstone/txnData_raw_sorted.csv')

# %%
# This cell takes approx. 8 min to run!
reader = csv.DictReader(open('/Users/rebeccamqamelo/Desktop/Capstone/txnData_raw_sorted.csv'))

txnData_dict = {}
for row in reader:
    date = row['timeset']
    sender_key = row['source']
    receiver_key = row['target']
    if sender_key in txnData_dict: # user's dict has already been created
        txnData_dict[sender_key].append({date: row})
    else:
        txnData_dict[sender_key] = [] # empty array to contain dict of each txn for that user
        txnData_dict[sender_key].append({date: row}) 
        
    if receiver_key in txnData_dict: # other user's dict has already been created
        txnData_dict[receiver_key].append({date: row})
    else:
        txnData_dict[receiver_key] = [] # empty array to contain dict of each txn for the other user
        txnData_dict[receiver_key].append({date: row})

# %%
# Save the dict for faster processing next time
"""
w = csv.writer(open("/Users/rebeccamqamelo/Desktop/Capstone/txnData_dict.csv", "w"))
for key, val in txnData_dict.items():
    w.writerow([key, val])
"""

# %%
sample_from(txnData_dict)
# Out:
# {'0xEDA5C9B75Fdb3B9bdAB987A704632280Cf93084F': [{'2020-01-25': OrderedDict([('',
#                  '0'),
#                 ('id', '1'),
#                 ('timeset', '2020-01-25'),
#                 ('transfer_subtype', 'DISBURSEMENT'),
#                 ('transfer_use', ''),
#                 ('source', '0xEDA5C9B75Fdb3B9bdAB987A704632280Cf93084F'),
#                 ('s_comm_tkn', 'None'),
#                 ('s_gender', 'system'),
#                 ('s_location_path', 'None'),
#                 ('s_location_lat', 'None'),
#                 ('s_location_lon', 'None'),
#                 ('s_business_type', 'System'),
#                 ('target', '0x245fc81fe385450Dc0f4787668e47c903C00b0A1'),
#                 ('t_comm_tkn', 'None'),
#                 ('t_gender', 'unknown gender'),
#                 ('t_location_path', 'Kilifi,Kilifi,Coastal Kenya'),
#                 ('t_location_lat', '39.85'),
#                 ('t_location_lon', '-3.6333'),
#                 ('t_business_type', 'Savings Group'),
#                 ('tx_token', ''),
#                 ('weight', '18000.0'),
#                 ('type', 'directed'),
#                 ('token_name', 'Sarafu'),
#                 ('token_address',
#                  '0x0Fd6e8F2320C90e9D4b3A5bd888c4D556d20AbD4')])},
#   {'2020-01-25': OrderedDict([('', '1'),
#                 ('id', '2'),
#                 ('timeset', '2020-01-25'),
#                 ('transfer_subtype', 'DISBURSEMENT'),
#                 ('transfer_use', ''),
#                 ('source', '0xEDA5C9B75Fdb3B9bdAB987A704632280Cf93084F'),
#                 ('s_comm_tkn', 'None'),
#                 ('s_gender', 'system'),
#                 ('s_location_path', 'None'),
#                 ('s_location_lat', 'None'),
#                 ('s_location_lon', 'None'),
#                 ('s_business_type', 'System'),
#                 ('target', '0xC1697C1326fD192438515fE2F7E4cCb0C705C5d2'),
#                 ('t_comm_tkn', 'None'),
#                 ('t_gender', 'unknown gender'),
#                 ('t_location_path', 'Kilifi,Kilifi,Coastal Kenya'),
#                 ('t_location_lat', '39.85'),
#                 ('t_location_lon', '-3.6333'),
#                 ('t_business_type', 'Farming/Labour'),
#                 ('tx_token', ''),
#                 ('weight', '9047.660892016263'),
#                 ('type', 'directed'),
#                 ('token_name', 'Sarafu'),
#                 ('token_address',
#                  '0x0Fd6e8F2320C90e9D4b3A5bd888c4D556d20AbD4')])},
#   {'2020-01-25': OrderedDict([('', '2'),
#                 ('id', '3'),
#                 ('timeset', '2020-01-25'),
#                 ('transfer_subtype', 'DISBURSEMENT'),
#                 ('transfer_use', ''),
#                 ('source', '0xEDA5C9B75Fdb3B9bdAB987A704632280Cf93084F'),
#                 ('s_comm_tkn', 'None'),
#                 ('s_gender', 'system'),
#                 ('s_location_path', 'None'),
#                 ('s_location_lat', 'None'),
#                 ('s_location_lon', 'None'),
#                 ('s_business_type', 'System'),
#                 ('target', '0xBAB77A20a757e8438DfaBF01D5F36DD12d862B31'),
#                 ('t_comm_tkn', 'None'),
#                 ('t_gender', 'unknown gender'),
#                 ('t_location_path', 'Kilifi,Kilifi,Coastal Kenya'),
#                 ('t_location_lat', '39.85'),
#                 ('t_location_lon', '-3.6333'),
#                 ('t_business_type', 'Farming/Labour'),
#                 ('tx_token', ''),
#                 ('weight', '25378.72600155909'),
#                 ('type', 'directed'),
#                 ('token_name', 'Sarafu'),
#                 ('token_address',
#                  '0x0Fd6e8F2320C90e9D4b3A5bd888c4D556d20AbD4')])},
#   {'2020-01-25': OrderedDict([('', '3'),
#                 ('id', '4'),
#                 ('timeset', '2020-01-25'),
#                 ('transfer_subtype', 'DISBURSEMENT'),
#                 ('transfer_use', ''),
#                 ('source', '0xEDA5C9B75Fdb3B9bdAB987A704632280Cf93084F'),
#                 ('s_comm_tkn', 'None'),
#                 ('s_gender', 'system'),
#                 ('s_location_path', 'None'),
#                 ('s_location_lat', 'None'),
#                 ('s_location_lon', 'None'),
#                 ('s_business_type', 'System'),
#                 ('target', '0xD95954e3fCd2f09A6Be5931D24f731eFa63BF435'),
#                 ('t_comm_tkn', 'None'),
#                 ('t_gender', 'unknown gender'),
#                 ('t_location_path', 'Kilifi,Kilifi,Coastal Kenya'),
#                 ('t_location_lat', '39.85'),
#                 ('t_location_lon', '-3.6333'),
#                 ('t_business_type', 'Health'),
#                 ('tx_token', ''),
#                 ('weight', '4495.932576319984'),
#                 ('type', 'directed'),
#                 ('token_name', 'Sarafu'),
#                 ('token_address',
#                  '0x0Fd6e8F2320C90e9D4b3A5bd888c4D556d20AbD4')])},
#   {'2020-01-26': OrderedDict([('', '4364'),
#                 ('id', '4367'),
#                 ('timeset', '2020-01-26'),
#                 ('transfer_subtype', 'DISBURSEMENT'),
#                 ('transfer_use', ''),
#                 ('source', '0xEDA5C9B75Fdb3B9bdAB987A704632280Cf93084F'),
#                 ('s_comm_tkn', 'None'),
#                 ('s_gender', 'system'),
#                 ('s_location_path', 'None'),
#                 ('s_location_lat', 'None'),
#                 ('s_location_lon', 'None'),
#                 ('s_business_type', 'System'),
#                 ('target', '0xa55c66a5a2D471176Ea70a11Ae2831E32022c6d7'),
#                 ('t_comm_tkn', 'None'),
#                 ('t_gender', 'male'),
#                 ('t_location_path', 'Bofu,Kwale,Coastal Kenya'),
#                 ('t_location_lat', '39.4333'),
#                 ('t_location_lon', '-3.9666'),
#                 ('t_business_type', 'Farming/Labour'),
#                 ('tx_token', ''),
#                 ('weight', '430.0'),
#                 ('type', 'directed'),
#                 ('token_name', 'Sarafu'),
#                 ('token_address',
#                  '0x0Fd6e8F2320C90e9D4b3A5bd888c4D556d20AbD4')])},
#   {'2020-01-26': OrderedDict([('', '4363'),
#                 ('id', '4366'),
#                 ('timeset', '2020-01-26'),
#                 ('transfer_subtype', 'DISBURSEMENT'),
#                 ('transfer_use', ''),
#                 ('source', '0xEDA5C9B75Fdb3B9bdAB987A704632280Cf93084F'),
#                 ('s_comm_tkn', 'None'),
#                 ('s_gender', 'system'),
#                 ('s_location_path', 'None'),
#                 ('s_location_lat', 'None'),
#                 ('s_location_lon', 'None'),
#                 ('s_business_type', 'System'),
#                 ('target', '0x3B441A9aD84f76A4835607f28eF746224E7c51D9'),
#                 ('t_comm_tkn', 'None'),
#                 ('t_gender', 'male'),
#                 ('t_location_path', 'None'),
#                 ('t_location_lat', 'None'),
#                 ('t_location_lon', 'None'),
#                 ('t_business_type', 'Farming/Labour'),
#                 ('tx_token', ''),
#                 ('weight', '50.0'),
#                 ('type', 'directed'),
#                 ('token_name', 'Sarafu'),
#                 ('token_address',
#                  '0x0Fd6e8F2320C90e9D4b3A5bd888c4D556d20AbD4')])},
#   {'2020-01-26': OrderedDict([('', '4362'),
#                 ('id', '4365'),
#                 ('timeset', '2020-01-26'),
#                 ('transfer_subtype', 'DISBURSEMENT'),
#                 ('transfer_use', ''),
#                 ('source', '0xEDA5C9B75Fdb3B9bdAB987A704632280Cf93084F'),
#                 ('s_comm_tkn', 'None'),
#                 ('s_gender', 'system'),
#                 ('s_location_path', 'None'),
#                 ('s_location_lat', 'None'),
#                 ('s_location_lon', 'None'),
#                 ('s_business_type', 'System'),
#                 ('target', '0x84b89c706270368B3F36f77D496c7A2322D71c39'),
#                 ('t_comm_tkn', 'None'),
#                 ('t_gender', 'male'),
#                 ('t_location_path', 'Lindi,Nairobi'),
#                 ('t_location_lat', '36.79284123001965'),
#                 ('t_location_lon', '-1.31516185'),
#                 ('t_business_type', 'Shop'),
#                 ('tx_token', ''),
#                 ('weight', '60.0'),
#                 ('type', 'directed'),
#                 ('token_name', 'Sarafu'),
#                 ('token_address',
#                  '0x0Fd6e8F2320C90e9D4b3A5bd888c4D556d20AbD4')])},
#   {'2020-01-26': OrderedDict([('', '4361'),
#                 ('id', '4364'),
#                 ('timeset', '2020-01-26'),
#                 ('transfer_subtype', 'DISBURSEMENT'),
#                 ('transfer_use', ''),
#                 ('source', '0xEDA5C9B75Fdb3B9bdAB987A704632280Cf93084F'),
#                 ('s_comm_tkn', 'None'),
#                 ('s_gender', 'system'),
#                 ('s_location_path', 'None'),
#                 ('s_location_lat', 'None'),
#                 ('s_location_lon', 'None'),
#                 ('s_business_type', 'System'),
#                 ('target', '0xCaC4f148aea5d3545Bf37E442f2fCC12dE42Ba5d'),
#                 ('t_comm_tkn', 'None'),
#                 ('t_gender', 'female'),
#                 ('t_location_path', 'Lindi,Nairobi'),
#                 ('t_location_lat', '36.79284123001965'),
#                 ('t_location_lon', '-1.31516185'),
#                 ('t_business_type', 'Food/Water'),
#                 ('tx_token', ''),
#                 ('weight', '10.0'),
#                 ('type', 'directed'),
#                 ('token_name', 'Sarafu'),
#                 ('token_address',
#                  '0x0Fd6e8F2320C90e9D4b3A5bd888c4D556d20AbD4')])},
#   {'2020-01-26': OrderedDict([('', '4360'),
#                 ('id', '4363'),
#                 ('timeset', '2020-01-26'),
#                 ('transfer_subtype', 'DISBURSEMENT'),
#                 ('transfer_use', ''),
#                 ('source', '0xEDA5C9B75Fdb3B9bdAB987A704632280Cf93084F'),
#                 ('s_comm_tkn', 'None'),
#                 ('s_gender', 'system'),
#                 ('s_location_path', 'None'),
#                 ('s_location_lat', 'None'),
#                 ('s_location_lon', 'None'),
#                 ('s_business_type', 'System'),
#                 ('target', '0x74DA4e36605d9E4a212e2cCBCF2518df850b95fc'),
#                 ('t_comm_tkn', 'None'),
#                 ('t_gender', 'female'),
#                 ('t_location_path', 'Congo,Kawangware,Nairobi'),
#                 ('t_location_lat', '36.75400404068876'),
#                 ('t_location_lon', '-1.2877494999999999'),
#                 ('t_business_type', 'Fuel/Energy'),
#                 ('tx_token', ''),
#                 ('weight', '410.0'),
#                 ('type', 'directed'),
#                 ('token_name', 'Sarafu'),
#                 ('token_address',
#                  '0x0Fd6e8F2320C90e9D4b3A5bd888c4D556d20AbD4')])},
#   {'2020-01-26': OrderedDict([('', '4359'),
#                 ('id', '4362'),
#                 ('timeset', '2020-01-26'),
#                 ('transfer_subtype', 'DISBURSEMENT'),
#                 ('transfer_use', ''),
#                 ('source', '0xEDA5C9B75Fdb3B9bdAB987A704632280Cf93084F'),
#                 ('s_comm_tkn', 'None'),
#                 ('s_gender', 'system'),
#                 ('s_location_path', 'None'),
#                 ('s_location_lat', 'None'),
#                 ('s_location_lon', 'None'),
#                 ('s_business_type', 'System'),
#                 ('target', '0x19136a18E4c4F8a50270A13a23e37771912003cA'),
#                 ('t_comm_tkn', 'None'),
#                 ('t_gender', 'female'),
#                 ('t_location_path', 'Mnyenzeni,Kwale,Coastal Kenya'),
#                 ('t_location_lat', '39.5'),
#                 ('t_location_lon', '-3.9833'),
#                 ('t_business_type', 'Shop'),
#                 ('tx_token', ''),
#                 ('weight', '60.0'),
#                 ('type', 'directed'),
#                 ('token_name', 'Sarafu'),
#                 ('token_address',
#                  '0x0Fd6e8F2320C90e9D4b3A5bd888c4D556d20AbD4')])},
#   {'2020-01-26': OrderedDict([('', '4358'),
#                 ('id', '4361'),
#                 ('timeset', '2020-01-26'),
#                 ('transfer_subtype', 'DISBURSEMENT'),
#                 ('transfer_use', ''),
#                 ('source', '0xEDA5C9B75Fdb3B9bdAB987A704632280Cf93084F'),
#                 ('s_comm_tkn', 'None'),
#                 ('s_gender', 'system'),
#                 ('s_location_path', 'None'),
#                 ('s_location_lat', 'None'),
#                 ('s_location_lon', 'None'),
#                 ('s_business_type', 'System'),
#                 ('target', '0x91d2F895764A35fb7b8A7069d2506fA19F0F887E'),
#                 ('t_comm_tkn', 'None'),
#                 ('t_gender', 'male'),
#                 ('t_location_path', 'None'),
#                 ('t_location_lat', 'None'),
#                 ('t_location_lon', 'None'),
#                 ('t_business_type', 'Farming/Labour'),
#                 ('tx_token', ''),
#                 ('weight', '217.0'),
#                 ('type', 'directed'),
#                 ('token_name', 'Sarafu'),
#                 ('token_address',
#                  '0x0Fd6e8F2320C90e9D4b3A5bd888c4D556d20AbD4')])},
#   {'2020-01-26': OrderedDict([('', '4357'),
#                 ('id', '4360'),
#                 ('timeset', '2020-01-26'),
#                 ('transfer_subtype', 'DISBURSEMENT'),
#                 ('transfer_use', ''),
#                 ('source', '0xEDA5C9B75Fdb3B9bdAB987A704632280Cf93084F'),
#                 ('s_comm_tkn', 'None'),
#                 ('s_gender', 'system'),
#                 ('s_location_path', 'None'),
#                 ('s_location_lat', 'None'),
#                 ('s_location_lon', 'None'),
#                 ('s_business_type', 'System'),
#                 ('target', '0xfd9146d9b6058fca75E82998BDAB0296a4b0bC02'),
#                 ('t_comm_tkn', 'None'),
#                 ('t_gender', 'female'),
#                 ('t_location_path', 'Mnyenzeni,Kwale,Coastal Kenya'),
#                 ('t_location_lat', '39.5'),
#                 ('t_location_lon', '-3.9833'),
#                 ('t_business_type', 'Farming/Labour'),
#                 ('tx_token', ''),
#                 ('weight', '459.9496177204974'),
#                 ('type', 'directed'),
#                 ('token_name', 'Sarafu'),
#                 ('token_address',
#                  '0x0Fd6e8F2320C90e9D4b3A5bd888c4D556d20AbD4')])},
#   {'2020-01-26': OrderedDict([('', '4356'),
#                 ('id', '4359'),
#                 ('timeset', '2020-01-26'),
#                 ('transfer_subtype', 'DISBURSEMENT'),
#                 ('transfer_use', ''),
#                 ('source', '0xEDA5C9B75Fdb3B9bdAB987A704632280Cf93084F'),
#                 ('s_comm_tkn', 'None'),
#                 ('s_gender', 'system'),
#                 ('s_location_path', 'None'),
#                 ('s_location_lat', 'None'),
#                 ('s_location_lon', 'None'),
#                 ('s_business_type', 'System'),
#                 ('target', '0xc11A2f185895219930794F44E56135fb6eB885cC'),
#                 ('t_comm_tkn', 'None'),
#                 ('t_gender', 'female'),
#                 ('t_location_path', 'None'),
#                 ('t_location_lat', 'None'),
#                 ('t_location_lon', 'None'),
#                 ('t_business_type', 'Transport'),
#                 ('tx_token', ''),
#                 ('weight', '400.0'),
#                 ('type', 'directed'),
#                 ('token_name', 'Sarafu'),
#                 ('token_address',
#                  '0x0Fd6e8F2320C90e9D4b3A5bd888c4D556d20AbD4')])},
#   {'2020-01-26': OrderedDict([('', '4355'),
#                 ('id', '4358'),
#                 ('timeset', '2020-01-26'),
#                 ('transfer_subtype', 'DISBURSEMENT'),
#                 ('transfer_use', ''),
#                 ('source', '0xEDA5C9B75Fdb3B9bdAB987A704632280Cf93084F'),
#                 ('s_comm_tkn', 'None'),
#                 ('s_gender', 'system'),
#                 ('s_location_path', 'None'),
#                 ('s_location_lat', 'None'),
#                 ('s_location_lon', 'None'),
#                 ('s_business_type', 'System'),
#                 ('target', '0xD159D01761Bdf159B63Bc74Ea4236fbc6aee7D5a'),
#                 ('t_comm_tkn', 'None'),
#                 ('t_gender', 'female'),
#                 ('t_location_path', 'Congo,Kawangware,Nairobi'),
#                 ('t_location_lat', '36.75400404068876'),
#                 ('t_location_lon', '-1.2877494999999999'),
#                 ('t_business_type', 'Farming/Labour'),
#                 ('tx_token', ''),
#                 ('weight', '60.0'),
#                 ('type', 'directed'),
#                 ('token_name', 'Sarafu'),
#                 ('token_address',
#                  '0x0Fd6e8F2320C90e9D4b3A5bd888c4D556d20AbD4')])},
#   {'2020-01-26': OrderedDict([('', '4353'),
#                 ('id', '4356'),
#                 ('timeset', '2020-01-26'),
#                 ('transfer_subtype', 'DISBURSEMENT'),
#                 ('transfer_use', ''),
#                 ('source', '0xEDA5C9B75Fdb3B9bdAB987A704632280Cf93084F'),
#                 ('s_comm_tkn', 'None'),
#                 ('s_gender', 'system'),
#                 ('s_location_path', 'None'),
#                 ('s_location_lat', 'None'),
#                 ('s_location_lon', 'None'),
#                 ('s_business_type', 'System'),
#                 ('target', '0x175D369ecCA29C2eDE9c5c249EcD8d81405c28E6'),
#                 ('t_comm_tkn', 'None'),
#                 ('t_gender', 'male'),
#                 ('t_location_path', 'None'),
#                 ('t_location_lat', 'None'),
#                 ('t_location_lon', 'None'),
#                 ('t_business_type', 'Farming/Labour'),
#                 ('tx_token', ''),
#                 ('weight', '137.98693543597471'),
#                 ('type', 'directed'),
#                 ('token_name', 'Sarafu'),
#                 ('token_address',
#                  '0x0Fd6e8F2320C90e9D4b3A5bd888c4D556d20AbD4')])},
#   {'2020-01-26': OrderedDict([('', '4365'),
#                 ('id', '4368'),
#                 ('timeset', '2020-01-26'),
#                 ('transfer_subtype', 'DISBURSEMENT'),
#                 ('transfer_use', ''),
#                 ('source', '0xEDA5C9B75Fdb3B9bdAB987A704632280Cf93084F'),
#                 ('s_comm_tkn', 'None'),
#                 ('s_gender', 'system'),
#                 ('s_location_path', 'None'),
#                 ('s_location_lat', 'None'),
#                 ('s_location_lon', 'None'),
#                 ('s_business_type', 'System'),
#                 ('target', '0x627E5C68C7738B0Df21061882B284365A9E3141e'),
#                 ('t_comm_tkn', 'None'),
#                 ('t_gender', 'male'),
#                 ('t_location_path', 'Bofu,Kwale,Coastal Kenya'),
#                 ('t_location_lat', '39.4333'),
#                 ('t_location_lon', '-3.9666'),
#                 ('t_business_type', 'Transport'),
#                 ('tx_token', ''),
#                 ('weight', '400.0'),
#                 ('type', 'directed'),
#                 ('token_name', 'Sarafu'),
#                 ('token_address',
#                  '0x0Fd6e8F2320C90e9D4b3A5bd888c4D556d20AbD4')])},
#   {'2020-01-26': OrderedDict([('', '4352'),
#                 ('id', '4355'),
#                 ('timeset', '2020-01-26'),
#                 ('transfer_subtype', 'DISBURSEMENT'),
#                 ('transfer_use', ''),
#                 ('source', '0xEDA5C9B75Fdb3B9bdAB987A704632280Cf93084F'),
#                 ('s_comm_tkn', 'None'),
#                 ('s_gender', 'system'),
#                 ('s_location_path', 'None'),
#                 ('s_location_lat', 'None'),
#                 ('s_location_lon', 'None'),
#                 ('s_business_type', 'System'),
#                 ('target', '0xc91d6ca6da8E68e987a14Bea5377747Bf397B0AB'),
#                 ('t_comm_tkn', 'None'),
#                 ('t_gender', 'male'),
#                 ('t_location_path', 'None'),
#                 ('t_location_lat', 'None'),
#                 ('t_location_lon', 'None'),
#                 ('t_business_type', 'Farming/Labour'),
#                 ('tx_token', ''),
#                 ('weight', '400.0'),
#                 ('type', 'directed'),
#                 ('token_name', 'Sarafu'),
#                 ('token_address',
#                  '0x0Fd6e8F2320C90e9D4b3A5bd888c4D556d20AbD4')])},
#   {'2020-01-26': OrderedDict([('', '4351'),
#                 ('id', '4354'),
#                 ('timeset', '2020-01-26'),
#                 ('transfer_subtype', 'DISBURSEMENT'),
#                 ('transfer_use', ''),
#                 ('source', '0xEDA5C9B75Fdb3B9bdAB987A704632280Cf93084F'),
#                 ('s_comm_tkn', 'None'),
#                 ('s_gender', 'system'),
#                 ('s_location_path', 'None'),
#                 ('s_location_lat', 'None'),
#                 ('s_location_lon', 'None'),
#                 ('s_business_type', 'System'),
#                 ('target', '0x5C987aAE1a2B95ac28500035ade22cF8E7B5e455'),
#                 ('t_comm_tkn', 'None'),
#                 ('t_gender', 'female'),
#                 ('t_location_path', 'Congo,Kawangware,Nairobi'),
#                 ('t_location_lat', '36.75400404068876'),
#                 ('t_location_lon', '-1.2877494999999999'),
#                 ('t_business_type', 'Food/Water'),
#                 ('tx_token', ''),
#                 ('weight', '60.0'),
#                 ('type', 'directed'),
#                 ('token_name', 'Sarafu'),
#                 ('token_address',
#                  '0x0Fd6e8F2320C90e9D4b3A5bd888c4D556d20AbD4')])},
#   {'2020-01-26': OrderedDict([('', '4350'),
#                 ('id', '4353'),
#                 ('timeset', '2020-01-26'),
#                 ('transfer_subtype', 'DISBURSEMENT'),
#                 ('transfer_use', ''),
#                 ('source', '0xEDA5C9B75Fdb3B9bdAB987A704632280Cf93084F'),
#                 ('s_comm_tkn', 'None'),
#                 ('s_gender', 'system'),
#                 ('s_location_path', 'None'),
#                 ('s_location_lat', 'None'),
#                 ('s_location_lon', 'None'),
#                 ('s_business_type', 'System'),
#                 ('target', '0x4924Ec4906cf245B2ba12A57aAfF18618803c9A5'),
#                 ('t_comm_tkn', 'None'),
#                 ('t_gender', 'female'),
#                 ('t_location_path', 'Bofu,Kwale,Coastal Kenya'),
#                 ('t_location_lat', '39.4333'),
#                 ('t_location_lon', '-3.9666'),
#                 ('t_business_type', 'Farming/Labour'),
#                 ('tx_token', ''),
#                 ('weight', '5.0'),
#                 ('type', 'directed'),
#                 ('token_name', 'Sarafu'),
#                 ('token_address',
#                  '0x0Fd6e8F2320C90e9D4b3A5bd888c4D556d20AbD4')])},
#   {'2020-01-26': OrderedDict([('', '4349'),
#                 ('id', '4352'),
#                 ('timeset', '2020-01-26'),
#                 ('transfer_subtype', 'DISBURSEMENT'),
#                 ('transfer_use', ''),
#                 ('source', '0xEDA5C9B75Fdb3B9bdAB987A704632280Cf93084F'),
#                 ('s_comm_tkn', 'None'),
#                 ('s_gender', 'system'),
#                 ('s_location_path', 'None'),
#                 ('s_location_lat', 'None'),
#                 ('s_location_lon', 'None'),
#                 ('s_business_type', 'System'),
#                 ('target', '0x93e398ad6b465e053C9E7d0cF2813d524A7c4eFb'),
#                 ('t_comm_tkn', 'None'),
#                 ('t_gender', 'female'),
#                 ('t_location_path', 'Congo,Kawangware,Nairobi'),
#                 ('t_location_lat', '36.75400404068876'),
#                 ('t_location_lon', '-1.2877494999999999'),
#                 ('t_business_type', 'Food/Water'),
#                 ('tx_token', ''),
#                 ('weight', '400.0'),
#                 ('type', 'directed'),
#                 ('token_name', 'Sarafu'),
#                 ('token_address',
#                  '0x0Fd6e8F2320C90e9D4b3A5bd888c4D556d20AbD4')])},
#   {'2020-01-26': OrderedDict([('', '4348'),
#                 ('id', '4351'),
#                 ('timeset', '2020-01-26'),
#                 ('transfer_subtype', 'DISBURSEMENT'),
#                 ('transfer_use', ''),
#                 ('source', '0xEDA5C9B75Fdb3B9bdAB987A704632280Cf93084F'),
#                 ('s_comm_tkn', 'None'),
#                 ('s_gender', 'system'),
#                 ('s_location_path', 'None'),
#                 ('s_location_lat', 'None'),
#                 ('s_location_lon', 'None'),
#                 ('s_business_type', 'System'),
#                 ('target', '0x5407b7f115058fAe68aEEA3B1cf7da516A4BeAd4'),
#                 ('t_comm_tkn', 'None'),
#                 ('t_gender', 'female'),
#                 ('t_location_path', 'Bofu,Kwale,Coastal Kenya'),
#                 ('t_location_lat', '39.4333'),
#                 ('t_location_lon', '-3.9666'),
#                 ('t_business_type', 'Food/Water'),
#                 ('tx_token', ''),
#                 ('weight', '60.0'),
#                 ('type', 'directed'),
#                 ('token_name', 'Sarafu'),
#                 ('token_address',
#                  '0x0Fd6e8F2320C90e9D4b3A5bd888c4D556d20AbD4')])},
#   {'2020-01-26': OrderedDict([('', '4347'),
#                 ('id', '4350'),
#                 ('timeset', '2020-01-26'),
#                 ('transfer_subtype', 'DISBURSEMENT'),
#                 ('transfer_use', ''),
#                 ('source', '0xEDA5C9B75Fdb3B9bdAB987A704632280Cf93084F'),
#                 ('s_comm_tkn', 'None'),
#                 ('s_gender', 'system'),
#                 ('s_location_path', 'None'),
#                 ('s_location_lat', 'None'),
#                 ('s_location_lon', 'None'),
#                 ('s_business_type', 'System'),
#                 ('target', '0x41665dE4f2ed06C27cb5D84D8C702fF0e2d9737E'),
#                 ('t_comm_tkn', 'None'),
#                 ('t_gender', 'female'),
#                 ('t_location_path', 'Congo,Kawangware,Nairobi'),
#                 ('t_location_lat', '36.75400404068876'),
#                 ('t_location_lon', '-1.2877494999999999'),
#                 ('t_business_type', 'Farming/Labour'),
#                 ('tx_token', ''),
#                 ('weight', '400.0'),
#                 ('type', 'directed'),
#                 ('token_name', 'Sarafu'),
#                 ('token_address',
#                  '0x0Fd6e8F2320C90e9D4b3A5bd888c4D556d20AbD4')])},
#   {'2020-01-26': OrderedDict([('', '4346'),
#                 ('id', '4349'),
#                 ('timeset', '2020-01-26'),
#                 ('transfer_subtype', 'DISBURSEMENT'),
#                 ('transfer_use', ''),
#                 ('source', '0xEDA5C9B75Fdb3B9bdAB987A704632280Cf93084F'),
#                 ('s_comm_tkn', 'None'),
#                 ('s_gender', 'system'),
#                 ('s_location_path', 'None'),
#                 ('s_location_lat', 'None'),
#                 ('s_location_lon', 'None'),
#                 ('s_business_type', 'System'),
#                 ('target', '0x2b31AE0bA799007899c3B7EB2FC1688518D9F472'),
#                 ('t_comm_tkn', 'None'),
#                 ('t_gender', 'female'),
#                 ('t_location_path', 'None'),
#                 ('t_location_lat', 'None'),
#                 ('t_location_lon', 'None'),
#                 ('t_business_type', 'Farming/Labour'),
#                 ('tx_token', ''),
#                 ('weight', '105.0'),
#                 ('type', 'directed'),
#                 ('token_name', 'Sarafu'),
#                 ('token_address',
#                  '0x0Fd6e8F2320C90e9D4b3A5bd888c4D556d20AbD4')])},
#   {'2020-01-26': OrderedDict([('', '4345'),
#                 ('id', '4348'),
#                 ('timeset', '2020-01-26'),
#                 ('transfer_subtype', 'DISBURSEMENT'),
#                 ('transfer_use', ''),
#                 ('source', '0xEDA5C9B75Fdb3B9bdAB987A704632280Cf93084F'),
#                 ('s_comm_tkn', 'None'),
#                 ('s_gender', 'system'),
#                 ('s_location_path', 'None'),
#                 ('s_location_lat', 'None'),
#                 ('s_location_lon', 'None'),
#                 ('s_business_type', 'System'),
#                 ('target', '0x83Bd74d403447d5334ae7817A6f3844d10D02dd2'),
#                 ('t_comm_tkn', 'None'),
#                 ('t_gender', 'female'),
#                 ('t_location_path', 'Mnyenzeni,Kwale,Coastal Kenya'),
#                 ('t_location_lat', '39.5'),
#                 ('t_location_lon', '-3.9833'),
#                 ('t_business_type', 'Farming/Labour'),
#                 ('tx_token', ''),
#                 ('weight', '60.0'),
#                 ('type', 'directed'),
#                 ('token_name', 'Sarafu'),
#                 ('token_address',
#                  '0x0Fd6e8F2320C90e9D4b3A5bd888c4D556d20AbD4')])},
#   {'2020-01-26': OrderedDict([('', '4344'),
#                 ('id', '4347'),
#                 ('timeset', '2020-01-26'),
#                 ('transfer_subtype', 'DISBURSEMENT'),
#                 ('transfer_use', ''),
#                 ('source', '0xEDA5C9B75Fdb3B9bdAB987A704632280Cf93084F'),
#                 ('s_comm_tkn', 'None'),
#                 ('s_gender', 'system'),
#                 ('s_location_path', 'None'),
#                 ('s_location_lat', 'None'),
#                 ('s_location_lon', 'None'),
#                 ('s_business_type', 'System'),
#                 ('target', '0xC157C5cd25F216148359932DE8EA057e64C4CCF3'),
#                 ('t_comm_tkn', 'None'),
#                 ('t_gender', 'female'),
#                 ('t_location_path', 'None'),
#                 ('t_location_lat', 'None'),
#                 ('t_location_lon', 'None'),
#                 ('t_business_type', 'Farming/Labour'),
#                 ('tx_token', ''),
#                 ('weight', '10.0'),
#                 ('type', 'directed'),
#                 ('token_name', 'Sarafu'),
#                 ('token_address',
#                  '0x0Fd6e8F2320C90e9D4b3A5bd888c4D556d20AbD4')])},
#   {'2020-01-26': OrderedDict([('', '4354'),
#                 ('id', '4357'),
#                 ('timeset', '2020-01-26'),
#                 ('transfer_subtype', 'DISBURSEMENT'),
#                 ('transfer_use', ''),
#                 ('source', '0xEDA5C9B75Fdb3B9bdAB987A704632280Cf93084F'),
#                 ('s_comm_tkn', 'None'),
#                 ('s_gender', 'system'),
#                 ('s_location_path', 'None'),
#                 ('s_location_lat', 'None'),
#                 ('s_location_lon', 'None'),
#                 ('s_business_type', 'System'),
#                 ('target', '0xdfa58c35547427eEbA2f7E691a1f15374D45B70A'),
#                 ('t_comm_tkn', 'None'),
#                 ('t_gender', 'male'),
#                 ('t_location_path', 'None'),
#                 ('t_location_lat', 'None'),
#                 ('t_location_lon', 'None'),
#                 ('t_business_type', 'Transport'),
#                 ('tx_token', ''),
#                 ('weight', '100.0'),
#                 ('type', 'directed'),
#                 ('token_name', 'Sarafu'),
#                 ('token_address',
#                  '0x0Fd6e8F2320C90e9D4b3A5bd888c4D556d20AbD4')])},
#   {'2020-01-26': OrderedDict([('', '4366'),
#                 ('id', '4369'),
#                 ('timeset', '2020-01-26'),
#                 ('transfer_subtype', 'DISBURSEMENT'),
#                 ('transfer_use', ''),
#                 ('source', '0xEDA5C9B75Fdb3B9bdAB987A704632280Cf93084F'),
#                 ('s_comm_tkn', 'None'),
#                 ('s_gender', 'system'),
#                 ('s_location_path', 'None'),
#                 ('s_location_lat', 'None'),
#                 ('s_location_lon', 'None'),
#                 ('s_business_type', 'System'),
#                 ('target', '0xfa063D389b5de686096e6E2ECA688E23754A5d4e'),
#                 ('t_comm_tkn', 'None'),
#                 ('t_gender', 'male'),
#                 ('t_location_path', 'Bofu,Kwale,Coastal Kenya'),
#                 ('t_location_lat', '39.4333'),
#                 ('t_location_lon', '-3.9666'),
#                 ('t_business_type', 'Transport'),
#                 ('tx_token', ''),
#                 ('weight', '50.0'),
#                 ('type', 'directed'),
#                 ('token_name', 'Sarafu'),
#                 ('token_address',
#                  '0x0Fd6e8F2320C90e9D4b3A5bd888c4D556d20AbD4')])},
#   {'2020-01-26': OrderedDict([('', '4368'),
#                 ('id', '4371'),
#                 ('timeset', '2020-01-26'),
#                 ('transfer_subtype', 'DISBURSEMENT'),
#                 ('transfer_use', ''),
#                 ('source', '0xEDA5C9B75Fdb3B9bdAB987A704632280Cf93084F'),
#                 ('s_comm_tkn', 'None'),
#                 ('s_gender', 'system'),
#                 ('s_location_path', 'None'),
#                 ('s_location_lat', 'None'),
#                 ('s_location_lon', 'None'),
#                 ('s_business_type', 'System'),
#                 ('target', '0x2c53433420E799b9c745A960EbA01c946c2E3038'),
#                 ('t_comm_tkn', 'None'),
#                 ('t_gender', 'female'),
#                 ('t_location_path', 'Congo,Kawangware,Nairobi'),
#                 ('t_location_lat', '36.75400404068876'),
#                 ('t_location_lon', '-1.2877494999999999'),
#                 ('t_business_type', 'Savings Group'),
#                 ('tx_token', ''),
#                 ('weight', '9725.0'),
#                 ('type', 'directed'),
#                 ('token_name', 'Sarafu'),
#                 ('token_address',
#                  '0x0Fd6e8F2320C90e9D4b3A5bd888c4D556d20AbD4')])},
#   {'2020-01-26': OrderedDict([('', '4343'),
#                 ('id', '4346'),
#                 ('timeset', '2020-01-26'),
#                 ('transfer_subtype', 'DISBURSEMENT'),
#                 ('transfer_use', ''),
#                 ('source', '0xEDA5C9B75Fdb3B9bdAB987A704632280Cf93084F'),
#                 ('s_comm_tkn', 'None'),
#                 ('s_gender', 'system'),
#                 ('s_location_path', 'None'),
#                 ('s_location_lat', 'None'),
#                 ('s_location_lon', 'None'),
#                 ('s_business_type', 'System'),
#                 ('target', '0xb6Fda8E586372D5267d31A1115C59D5F5C0B7D3a'),
#                 ('t_comm_tkn', 'None'),
#                 ('t_gender', 'female'),
#                 ('t_location_path', 'Mnyenzeni,Kwale,Coastal Kenya'),
#                 ('t_location_lat', '39.5'),
#                 ('t_location_lon', '-3.9833'),
#                 ('t_business_type', 'Shop'),
#                 ('tx_token', ''),
#                 ('weight', '60.0'),
#                 ('type', 'directed'),
#                 ('token_name', 'Sarafu'),
#                 ('token_address',
#                  '0x0Fd6e8F2320C90e9D4b3A5bd888c4D556d20AbD4')])},
#   {'2020-01-26': OrderedDict([('', '4390'),
#                 ('id', '4393'),
#                 ('timeset', '2020-01-26'),
#                 ('transfer_subtype', 'DISBURSEMENT'),
#                 ('transfer_use', ''),
#                 ('source', '0xEDA5C9B75Fdb3B9bdAB987A704632280Cf93084F'),
#                 ('s_comm_tkn', 'None'),
#                 ('s_gender', 'system'),
#                 ('s_location_path', 'None'),
#                 ('s_location_lat', 'None'),
#                 ('s_location_lon', 'None'),
#                 ('s_business_type', 'System'),
#                 ('target', '0xaE8A9e500FcD5783CeAEF77B1f2CDe2D83Bc8DD5'),
#                 ('t_comm_tkn', 'None'),
#                 ('t_gender', 'male'),
#                 ('t_location_path', 'None'),
#                 ('t_location_lat', 'None'),
#                 ('t_location_lon', 'None'),
#                 ('t_business_type', 'Farming/Labour'),
#                 ('tx_token', ''),
#                 ('weight', '10.0'),
#                 ('type', 'directed'),
#                 ('token_name', 'Sarafu'),
#                 ('token_address',
#                  '0x0Fd6e8F2320C90e9D4b3A5bd888c4D556d20AbD4')])},
#   {'2020-01-26': OrderedDict([('', '4389'),
#                 ('id', '4392'),
#                 ('timeset', '2020-01-26'),
#                 ('transfer_subtype', 'DISBURSEMENT'),
#                 ('transfer_use', ''),
#                 ('source', '0xEDA5C9B75Fdb3B9bdAB987A704632280Cf93084F'),
#                 ('s_comm_tkn', 'None'),
#                 ('s_gender', 'system'),
#                 ('s_location_path', 'None'),
#                 ('s_location_lat', 'None'),
#                 ('s_location_lon', 'None'),
#                 ('s_business_type', 'System'),
#                 ('target', '0x8488616e70e83c7287C63298feB55aDdd5cb6d7d'),
#                 ('t_comm_tkn', 'None'),
#                 ('t_gender', 'female'),
#                 ('t_location_path', 'Mnyenzeni,Kwale,Coastal Kenya'),
#                 ('t_location_lat', '39.5'),
#                 ('t_location_lon', '-3.9833'),
#                 ('t_business_type', 'Farming/Labour'),
#                 ('tx_token', ''),
#                 ('weight', '465.0700572947074'),
#                 ('type', 'directed'),
#                 ('token_name', 'Sarafu'),
#                 ('token_address',
#                  '0x0Fd6e8F2320C90e9D4b3A5bd888c4D556d20AbD4')])},
#   {'2020-01-26': OrderedDict([('', '4388'),
#                 ('id', '4391'),
#                 ('timeset', '2020-01-26'),
#                 ('transfer_subtype', 'DISBURSEMENT'),
#                 ('transfer_use', ''),
#                 ('source', '0xEDA5C9B75Fdb3B9bdAB987A704632280Cf93084F'),
#                 ('s_comm_tkn', 'None'),
#                 ('s_gender', 'system'),
#                 ('s_location_path', 'None'),
#                 ('s_location_lat', 'None'),
#                 ('s_location_lon', 'None'),
#                 ('s_business_type', 'System'),
#                 ('target', '0xD75a16aAD9378F60AcD4BbFf5962b13f55dBe10E'),
#                 ('t_comm_tkn', 'None'),
#                 ('t_gender', 'male'),
#                 ('t_location_path', 'Bofu,Kwale,Coastal Kenya'),
#                 ('t_location_lat', '39.4333'),
#                 ('t_location_lon', '-3.9666'),
#                 ('t_business_type', 'Farming/Labour'),
#                 ('tx_token', ''),
#                 ('weight', '470.0'),
#                 ('type', 'directed'),
#                 ('token_name', 'Sarafu'),
#                 ('token_address',
#                  '0x0Fd6e8F2320C90e9D4b3A5bd888c4D556d20AbD4')])},
#   {'2020-01-26': OrderedDict([('', '4387'),
#                 ('id', '4390'),
#                 ('timeset', '2020-01-26'),
#                 ('transfer_subtype', 'DISBURSEMENT'),
#                 ('transfer_use', ''),
#                 ('source', '0xEDA5C9B75Fdb3B9bdAB987A704632280Cf93084F'),
#                 ('s_comm_tkn', 'None'),
#                 ('s_gender', 'system'),
#                 ('s_location_path', 'None'),
#                 ('s_location_lat', 'None'),
#                 ('s_location_lon', 'None'),
#                 ('s_business_type', 'System'),
#                 ('target', '0xc3Bc68F71b6ffF6c14BfBb1533badb3F76699584'),
#                 ('t_comm_tkn', 'None'),
#                 ('t_gender', 'female'),
#                 ('t_location_path', 'Mnyenzeni,Kwale,Coastal Kenya'),
#                 ('t_location_lat', '39.5'),
#                 ('t_location_lon', '-3.9833'),
#                 ('t_business_type', 'Farming/Labour'),
#                 ('tx_token', ''),
#                 ('weight', '175.04004891583355'),
#                 ('type', 'directed'),
#                 ('token_name', 'Sarafu'),
#                 ('token_address',
#                  '0x0Fd6e8F2320C90e9D4b3A5bd888c4D556d20AbD4')])},
#   {'2020-01-26': OrderedDict([('', '4386'),
#                 ('id', '4389'),
#                 ('timeset', '2020-01-26'),
#                 ('transfer_subtype', 'DISBURSEMENT'),
#                 ('transfer_use', ''),
#                 ('source', '0xEDA5C9B75Fdb3B9bdAB987A704632280Cf93084F'),
#                 ('s_comm_tkn', 'None'),
#                 ('s_gender', 'system'),
#                 ('s_location_path', 'None'),
#                 ('s_location_lat', 'None'),
#                 ('s_location_lon', 'None'),
#                 ('s_business_type', 'System'),
#                 ('target', '0x5591F1d0431B6c2B49D7dDeA95080DefD155132E'),
#                 ('t_comm_tkn', 'None'),
#                 ('t_gender', 'female'),
#                 ('t_location_path', 'Mnyenzeni,Kwale,Coastal Kenya'),
#                 ('t_location_lat', '39.5'),
#                 ('t_location_lon', '-3.9833'),
#                 ('t_business_type', 'Farming/Labour'),
#                 ('tx_token', ''),
#                 ('weight', '93.72944939081744'),
#                 ('type', 'directed'),
#                 ('token_name', 'Sarafu'),
#                 ('token_address',
#                  '0x0Fd6e8F2320C90e9D4b3A5bd888c4D556d20AbD4')])},
#   {'2020-01-26': OrderedDict([('', '4385'),
#                 ('id', '4388'),
#                 ('timeset', '2020-01-26'),
#                 ('transfer_subtype', 'DISBURSEMENT'),
#                 ('transfer_use', ''),
#                 ('source', '0xEDA5C9B75Fdb3B9bdAB987A704632280Cf93084F'),
#                 ('s_comm_tkn', 'None'),
#                 ('s_gender', 'system'),
#                 ('s_location_path', 'None'),
#                 ('s_location_lat', 'None'),
#                 ('s_location_lon', 'None'),
#                 ('s_business_type', 'System'),
#                 ('target', '0xe0cdF2F26f347A97d1bDF1658155Ac36d51593CC'),
#                 ('t_comm_tkn', 'None'),
#                 ('t_gender', 'male'),
#                 ('t_location_path', 'Bofu,Kwale,Coastal Kenya'),
#                 ('t_location_lat', '39.4333'),
#                 ('t_location_lon', '-3.9666'),
#                 ('t_business_type', 'Farming/Labour'),
#                 ('tx_token', ''),
#                 ('weight', '154.0'),
#                 ('type', 'directed'),
#                 ('token_name', 'Sarafu'),
#                 ('token_address',
#                  '0x0Fd6e8F2320C90e9D4b3A5bd888c4D556d20AbD4')])},
#   {'2020-01-26': OrderedDict([('', '4384'),
#                 ('id', '4387'),
#                 ('timeset', '2020-01-26'),
#                 ('transfer_subtype', 'DISBURSEMENT'),
#                 ('transfer_use', ''),
#                 ('source', '0xEDA5C9B75Fdb3B9bdAB987A704632280Cf93084F'),
#                 ('s_comm_tkn', 'None'),
#                 ('s_gender', 'system'),
#                 ('s_location_path', 'None'),
#                 ('s_location_lat', 'None'),
#                 ('s_location_lon', 'None'),
#                 ('s_business_type', 'System'),
#                 ('target', '0x74DA5993e5bD892D424a46e75c02151AD35cEBE5'),
#                 ('t_comm_tkn', 'None'),
#                 ('t_gender', 'male'),
#                 ('t_location_path', 'Bofu,Kwale,Coastal Kenya'),
#                 ('t_location_lat', '39.4333'),
#                 ('t_location_lon', '-3.9666'),
#                 ('t_business_type', 'Farming/Labour'),
#                 ('tx_token', ''),
#                 ('weight', '415.0'),
#                 ('type', 'directed'),
#                 ('token_name', 'Sarafu'),
#                 ('token_address',
#                  '0x0Fd6e8F2320C90e9D4b3A5bd888c4D556d20AbD4')])},
#   {'2020-01-26': OrderedDict([('', '4383'),
#                 ('id', '4386'),
#                 ('timeset', '2020-01-26'),
#                 ('transfer_subtype', 'DISBURSEMENT'),
#                 ('transfer_use', ''),
#                 ('source', '0xEDA5C9B75Fdb3B9bdAB987A704632280Cf93084F'),
#                 ('s_comm_tkn', 'None'),
#                 ('s_gender', 'system'),
#                 ('s_location_path', 'None'),
#                 ('s_location_lat', 'None'),
#                 ('s_location_lon', 'None'),
#                 ('s_business_type', 'System'),
#                 ('target', '0xba55f649504F63c87987813FC2C99F75148bc5c9'),
#                 ('t_comm_tkn', 'None'),
#                 ('t_gender', 'male'),
#                 ('t_location_path', 'Mombasa,Mombasa,Coastal Kenya'),
#                 ('t_location_lat', '39.667169'),
#                 ('t_location_lon', '-4.05052'),
#                 ('t_business_type', 'Farming/Labour'),
#                 ('tx_token', ''),
#                 ('weight', '329.0'),
#                 ('type', 'directed'),
#                 ('token_name', 'Sarafu'),
#                 ('token_address',
#                  '0x0Fd6e8F2320C90e9D4b3A5bd888c4D556d20AbD4')])},
#   {'2020-01-26': OrderedDict([('', '4382'),
#                 ('id', '4385'),
#                 ('timeset', '2020-01-26'),
#                 ('transfer_subtype', 'DISBURSEMENT'),
#                 ('transfer_use', ''),
#                 ('source', '0xEDA5C9B75Fdb3B9bdAB987A704632280Cf93084F'),
#                 ('s_comm_tkn', 'None'),
#                 ('s_gender', 'system'),
#                 ('s_location_path', 'None'),
#                 ('s_location_lat', 'None'),
#                 ('s_location_lon', 'None'),
#                 ('s_business_type', 'System'),
#                 ('target', '0x97D60EA6EB3477Fa01299b6724038A5693d00B6b'),
#                 ('t_comm_tkn', 'None'),
#                 ('t_gender', 'female'),
#                 ('t_location_path', 'Majengo,Kwale,Coastal Kenya'),
#                 ('t_location_lat', '39.5'),
#                 ('t_location_lon', '-3.9666'),
#                 ('t_business_type', 'Farming/Labour'),
#                 ('tx_token', ''),
#                 ('weight', '50.0'),
#                 ('type', 'directed'),
#                 ('token_name', 'Sarafu'),
#                 ('token_address',
#                  '0x0Fd6e8F2320C90e9D4b3A5bd888c4D556d20AbD4')])},
#   {'2020-01-26': OrderedDict([('', '4381'),
#                 ('id', '4384'),
#                 ('timeset', '2020-01-26'),
#                 ('transfer_subtype', 'DISBURSEMENT'),
#                 ('transfer_use', ''),
#                 ('source', '0xEDA5C9B75Fdb3B9bdAB987A704632280Cf93084F'),
#                 ('s_comm_tkn', 'None'),
#                 ('s_gender', 'system'),
#                 ('s_location_path', 'None'),
#                 ('s_location_lat', 'None'),
#                 ('s_location_lon', 'None'),
#                 ('s_business_type', 'System'),
#                 ('target', '0x8720761F701e61c0da951B41B0E2c3467C48341C'),
#                 ('t_comm_tkn', 'None'),
#                 ('t_gender', 'male'),
#                 ('t_location_path', 'None'),
#                 ('t_location_lat', 'None'),
#                 ('t_location_lon', 'None'),
#                 ('t_business_type', 'Farming/Labour'),
#                 ('tx_token', ''),
#                 ('weight', '210.0'),
#                 ('type', 'directed'),
#                 ('token_name', 'Sarafu'),
#                 ('token_address',
#                  '0x0Fd6e8F2320C90e9D4b3A5bd888c4D556d20AbD4')])},
#   {'2020-01-26': OrderedDict([('', '4367'),
#                 ('id', '4370'),
#                 ('timeset', '2020-01-26'),
#                 ('transfer_subtype', 'DISBURSEMENT'),
#                 ('transfer_use', ''),
#                 ('source', '0xEDA5C9B75Fdb3B9bdAB987A704632280Cf93084F'),
#                 ('s_comm_tkn', 'None'),
#                 ('s_gender', 'system'),
#                 ('s_location_path', 'None'),
#                 ('s_location_lat', 'None'),
#                 ('s_location_lon', 'None'),
#                 ('s_business_type', 'System'),
#                 ('target', '0x82D1a5EEE85725f0E36B603e59f4Ebd222219e26'),
#                 ('t_comm_tkn', 'None'),
#                 ('t_gender', 'male'),
#                 ('t_location_path', 'Bofu,Kwale,Coastal Kenya'),
#                 ('t_location_lat', '39.4333'),
#                 ('t_location_lon', '-3.9666'),
#                 ('t_business_type', 'Transport'),
#                 ('tx_token', ''),
#                 ('weight', '50.0'),
#                 ('type', 'directed'),
#                 ('token_name', 'Sarafu'),
#                 ('token_address',
#                  '0x0Fd6e8F2320C90e9D4b3A5bd888c4D556d20AbD4')])},
#   {'2020-01-26': OrderedDict([('', '4380'),
#                 ('id', '4383'),
#                 ('timeset', '2020-01-26'),
#                 ('transfer_subtype', 'DISBURSEMENT'),
#                 ('transfer_use', ''),
#                 ('source', '0xEDA5C9B75Fdb3B9bdAB987A704632280Cf93084F'),
#                 ('s_comm_tkn', 'None'),
#                 ('s_gender', 'system'),
#                 ('s_location_path', 'None'),
#                 ('s_location_lat', 'None'),
#                 ('s_location_lon', 'None'),
#                 ('s_business_type', 'System'),
#                 ('target', '0x1A1EcC0fE010EbA2379dC30a5b05B3e268b27AE4'),
#                 ('t_comm_tkn', 'None'),
#                 ('t_gender', 'female'),
#                 ('t_location_path', 'Kangemi,Nairobi'),
#                 ('t_location_lat', '36.7525183'),
#                 ('t_location_lon', '-1.2654259'),
#                 ('t_business_type', 'Food/Water'),
#                 ('tx_token', ''),
#                 ('weight', '430.0'),
#                 ('type', 'directed'),
#                 ('token_name', 'Sarafu'),
#                 ('token_address',
#                  '0x0Fd6e8F2320C90e9D4b3A5bd888c4D556d20AbD4')])},
#   {'2020-01-26': OrderedDict([('', '4378'),
#                 ('id', '4381'),
#                 ('timeset', '2020-01-26'),
#                 ('transfer_subtype', 'DISBURSEMENT'),
#                 ('transfer_use', ''),
#                 ('source', '0xEDA5C9B75Fdb3B9bdAB987A704632280Cf93084F'),
# ...
#                 ('t_gender', 'system'),
#                 ('t_location_path', 'None'),
#                 ('t_location_lat', 'None'),
#                 ('t_location_lon', 'None'),
#                 ('t_business_type', 'System'),
#                 ('tx_token', ''),
#                 ('weight', '136111.0'),
#                 ('type', 'directed'),
#                 ('token_name', 'Sarafu'),
#                 ('token_address',
#                  '0x0Fd6e8F2320C90e9D4b3A5bd888c4D556d20AbD4')])},
#   {'2020-07-02': OrderedDict([('', '261138'),
#                 ('id', '354330'),
#                 ('timeset', '2020-07-02'),
#                 ('transfer_subtype', 'AGENT_OUT'),
#                 ('transfer_use', ''),
#                 ('source', '0xBA4c863BDb7d2E92933Ccb5bC4F67f2b70122d69'),
#                 ('s_comm_tkn', 'None'),
#                 ('s_gender', 'female'),
#                 ('s_location_path', 'Bofu,Kwale,Coastal Kenya'),
#                 ('s_location_lat', '39.4333'),
#                 ('s_location_lon', '-3.9666'),
#                 ('s_business_type', 'Savings Group'),
#                 ('target', '0x245fc81fe385450Dc0f4787668e47c903C00b0A1'),
#                 ('t_comm_tkn', 'None'),
#                 ('t_gender', 'female'),
#                 ('t_location_path', 'Kilifi,Kilifi,Coastal Kenya'),
#                 ('t_location_lat', '39.85'),
#                 ('t_location_lon', '-3.6333'),
#                 ('t_business_type', 'Savings Group'),
#                 ('tx_token', ''),
#                 ('weight', '30000.0'),
#                 ('type', 'directed'),
#                 ('token_name', 'Sarafu'),
#                 ('token_address',
#                  '0x0Fd6e8F2320C90e9D4b3A5bd888c4D556d20AbD4')])},
#   {'2020-07-07': OrderedDict([('', '274984'),
#                 ('id', '368521'),
#                 ('timeset', '2020-07-07'),
#                 ('transfer_subtype', 'AGENT_OUT'),
#                 ('transfer_use', ''),
#                 ('source', '0xBfac844A3D51A6928cAF960F942e7532a1AcD843'),
#                 ('s_comm_tkn', 'None'),
#                 ('s_gender', 'female'),
#                 ('s_location_path', 'Bofu,Kwale,Coastal Kenya'),
#                 ('s_location_lat', '39.4333'),
#                 ('s_location_lon', '-3.9666'),
#                 ('s_business_type', 'Savings Group'),
#                 ('target', '0x245fc81fe385450Dc0f4787668e47c903C00b0A1'),
#                 ('t_comm_tkn', 'None'),
#                 ('t_gender', 'female'),
#                 ('t_location_path', 'Kilifi,Kilifi,Coastal Kenya'),
#                 ('t_location_lat', '39.85'),
#                 ('t_location_lon', '-3.6333'),
#                 ('t_business_type', 'Savings Group'),
#                 ('tx_token', ''),
#                 ('weight', '15200.0'),
#                 ('type', 'directed'),
#                 ('token_name', 'Sarafu'),
#                 ('token_address',
#                  '0x0Fd6e8F2320C90e9D4b3A5bd888c4D556d20AbD4')])},
#   {'2020-07-08': OrderedDict([('', '277370'),
#                 ('id', '370972'),
#                 ('timeset', '2020-07-08'),
#                 ('transfer_subtype', 'RECLAMATION'),
#                 ('transfer_use', ''),
#                 ('source', '0x245fc81fe385450Dc0f4787668e47c903C00b0A1'),
#                 ('s_comm_tkn', 'None'),
#                 ('s_gender', 'female'),
#                 ('s_location_path', 'Kilifi,Kilifi,Coastal Kenya'),
#                 ('s_location_lat', '39.85'),
#                 ('s_location_lon', '-3.6333'),
#                 ('s_business_type', 'Savings Group'),
#                 ('target', '0xEDA5C9B75Fdb3B9bdAB987A704632280Cf93084F'),
#                 ('t_comm_tkn', 'None'),
#                 ('t_gender', 'system'),
#                 ('t_location_path', 'None'),
#                 ('t_location_lat', 'None'),
#                 ('t_location_lon', 'None'),
#                 ('t_business_type', 'System'),
#                 ('tx_token', ''),
#                 ('weight', '45200.0'),
#                 ('type', 'directed'),
#                 ('token_name', 'Sarafu'),
#                 ('token_address',
#                  '0x0Fd6e8F2320C90e9D4b3A5bd888c4D556d20AbD4')])},
#   {'2020-07-11': OrderedDict([('', '282526'),
#                 ('id', '376275'),
#                 ('timeset', '2020-07-11'),
#                 ('transfer_subtype', 'AGENT_OUT'),
#                 ('transfer_use', ''),
#                 ('source', '0x1b96fea1551ae6D0d5b0a33093252CF771fEF4f0'),
#                 ('s_comm_tkn', 'None'),
#                 ('s_gender', 'male'),
#                 ('s_location_path', 'None'),
#                 ('s_location_lat', 'None'),
#                 ('s_location_lon', 'None'),
#                 ('s_business_type', 'Savings Group'),
#                 ('target', '0x245fc81fe385450Dc0f4787668e47c903C00b0A1'),
#                 ('t_comm_tkn', 'None'),
#                 ('t_gender', 'female'),
#                 ('t_location_path', 'Kilifi,Kilifi,Coastal Kenya'),
#                 ('t_location_lat', '39.85'),
#                 ('t_location_lon', '-3.6333'),
#                 ('t_business_type', 'Savings Group'),
#                 ('tx_token', ''),
#                 ('weight', '19000.0'),
#                 ('type', 'directed'),
#                 ('token_name', 'Sarafu'),
#                 ('token_address',
#                  '0x0Fd6e8F2320C90e9D4b3A5bd888c4D556d20AbD4')])},
#   {'2020-07-12': OrderedDict([('', '285141'),
#                 ('id', '378968'),
#                 ('timeset', '2020-07-12'),
#                 ('transfer_subtype', 'AGENT_OUT'),
#                 ('transfer_use', ''),
#                 ('source', '0x67E31B994A3AB7D8DF9d3FE8c518D082f62f5b25'),
#                 ('s_comm_tkn', 'None'),
#                 ('s_gender', 'male'),
#                 ('s_location_path', 'Mukuru Kayaba Village,Makongeni,Nairobi'),
#                 ('s_location_lat', '36.84450844411661'),
#                 ('s_location_lon', '-1.3112602'),
#                 ('s_business_type', 'Savings Group'),
#                 ('target', '0x245fc81fe385450Dc0f4787668e47c903C00b0A1'),
#                 ('t_comm_tkn', 'None'),
#                 ('t_gender', 'female'),
#                 ('t_location_path', 'Kilifi,Kilifi,Coastal Kenya'),
#                 ('t_location_lat', '39.85'),
#                 ('t_location_lon', '-3.6333'),
#                 ('t_business_type', 'Savings Group'),
#                 ('tx_token', ''),
#                 ('weight', '18080.0'),
#                 ('type', 'directed'),
#                 ('token_name', 'Sarafu'),
#                 ('token_address',
#                  '0x0Fd6e8F2320C90e9D4b3A5bd888c4D556d20AbD4')])},
#   {'2020-07-25': OrderedDict([('', '318445'),
#                 ('id', '412866'),
#                 ('timeset', '2020-07-25'),
#                 ('transfer_subtype', 'AGENT_OUT'),
#                 ('transfer_use', ''),
#                 ('source', '0xd377Ed503761cD1210197F2298b67a2D5159eFB6'),
#                 ('s_comm_tkn', 'None'),
#                 ('s_gender', 'unknown gender'),
#                 ('s_location_path', 'Bofu,Kwale,Coastal Kenya'),
#                 ('s_location_lat', '39.4333'),
#                 ('s_location_lon', '-3.9666'),
#                 ('s_business_type', 'Savings Group'),
#                 ('target', '0x245fc81fe385450Dc0f4787668e47c903C00b0A1'),
#                 ('t_comm_tkn', 'None'),
#                 ('t_gender', 'female'),
#                 ('t_location_path', 'Kilifi,Kilifi,Coastal Kenya'),
#                 ('t_location_lat', '39.85'),
#                 ('t_location_lon', '-3.6333'),
#                 ('t_business_type', 'Savings Group'),
#                 ('tx_token', ''),
#                 ('weight', '5519.0'),
#                 ('type', 'directed'),
#                 ('token_name', 'Sarafu'),
#                 ('token_address',
#                  '0x0Fd6e8F2320C90e9D4b3A5bd888c4D556d20AbD4')])},
#   {'2020-07-28': OrderedDict([('', '323768'),
#                 ('id', '418327'),
#                 ('timeset', '2020-07-28'),
#                 ('transfer_subtype', 'RECLAMATION'),
#                 ('transfer_use', ''),
#                 ('source', '0x245fc81fe385450Dc0f4787668e47c903C00b0A1'),
#                 ('s_comm_tkn', 'None'),
#                 ('s_gender', 'female'),
#                 ('s_location_path', 'Kilifi,Kilifi,Coastal Kenya'),
#                 ('s_location_lat', '39.85'),
#                 ('s_location_lon', '-3.6333'),
#                 ('s_business_type', 'Savings Group'),
#                 ('target', '0xEDA5C9B75Fdb3B9bdAB987A704632280Cf93084F'),
#                 ('t_comm_tkn', 'None'),
#                 ('t_gender', 'system'),
#                 ('t_location_path', 'None'),
#                 ('t_location_lat', 'None'),
#                 ('t_location_lon', 'None'),
#                 ('t_business_type', 'System'),
#                 ('tx_token', ''),
#                 ('weight', '42599.0'),
#                 ('type', 'directed'),
#                 ('token_name', 'Sarafu'),
#                 ('token_address',
#                  '0x0Fd6e8F2320C90e9D4b3A5bd888c4D556d20AbD4')])},
#   {'2020-08-03': OrderedDict([('', '334895'),
#                 ('id', '429722'),
#                 ('timeset', '2020-08-03'),
#                 ('transfer_subtype', 'AGENT_OUT'),
#                 ('transfer_use', ''),
#                 ('source', '0x27Eb0D08E470Fe0B4A8684779d42532Ca9C320b3'),
#                 ('s_comm_tkn', 'None'),
#                 ('s_gender', 'male'),
#                 ('s_location_path', 'Congo,Kawangware,Nairobi'),
#                 ('s_location_lat', '36.75400404068876'),
#                 ('s_location_lon', '-1.2877494999999999'),
#                 ('s_business_type', 'Savings Group'),
#                 ('target', '0x245fc81fe385450Dc0f4787668e47c903C00b0A1'),
#                 ('t_comm_tkn', 'None'),
#                 ('t_gender', 'female'),
#                 ('t_location_path', 'Kilifi,Kilifi,Coastal Kenya'),
#                 ('t_location_lat', '39.85'),
#                 ('t_location_lon', '-3.6333'),
#                 ('t_business_type', 'Savings Group'),
#                 ('tx_token', ''),
#                 ('weight', '15000.0'),
#                 ('type', 'directed'),
#                 ('token_name', 'Sarafu'),
#                 ('token_address',
#                  '0x0Fd6e8F2320C90e9D4b3A5bd888c4D556d20AbD4')])},
#   {'2020-08-05': OrderedDict([('', '338644'),
#                 ('id', '433584'),
#                 ('timeset', '2020-08-05'),
#                 ('transfer_subtype', 'STANDARD'),
#                 ('transfer_use', ''),
#                 ('source', '0x245fc81fe385450Dc0f4787668e47c903C00b0A1'),
#                 ('s_comm_tkn', 'None'),
#                 ('s_gender', 'female'),
#                 ('s_location_path', 'Kilifi,Kilifi,Coastal Kenya'),
#                 ('s_location_lat', '39.85'),
#                 ('s_location_lon', '-3.6333'),
#                 ('s_business_type', 'Savings Group'),
#                 ('target', '0x27Eb0D08E470Fe0B4A8684779d42532Ca9C320b3'),
#                 ('t_comm_tkn', 'None'),
#                 ('t_gender', 'male'),
#                 ('t_location_path', 'Congo,Kawangware,Nairobi'),
#                 ('t_location_lat', '36.75400404068876'),
#                 ('t_location_lon', '-1.2877494999999999'),
#                 ('t_business_type', 'Savings Group'),
#                 ('tx_token', ''),
#                 ('weight', '15000.0'),
#                 ('type', 'directed'),
#                 ('token_name', 'Sarafu'),
#                 ('token_address',
#                  '0x0Fd6e8F2320C90e9D4b3A5bd888c4D556d20AbD4')])},
#   {'2020-08-11': OrderedDict([('', '353677'),
#                 ('id', '448892'),
#                 ('timeset', '2020-08-11'),
#                 ('transfer_subtype', 'DISBURSEMENT'),
#                 ('transfer_use', ''),
#                 ('source', '0xBDB3Bc887C3b70586BC25D04d89eC802b897fC5F'),
#                 ('s_comm_tkn', 'None'),
#                 ('s_gender', 'system'),
#                 ('s_location_path', 'None'),
#                 ('s_location_lat', 'None'),
#                 ('s_location_lon', 'None'),
#                 ('s_business_type', 'System'),
#                 ('target', '0x245fc81fe385450Dc0f4787668e47c903C00b0A1'),
#                 ('t_comm_tkn', 'None'),
#                 ('t_gender', 'female'),
#                 ('t_location_path', 'Kilifi,Kilifi,Coastal Kenya'),
#                 ('t_location_lat', '39.85'),
#                 ('t_location_lon', '-3.6333'),
#                 ('t_business_type', 'Savings Group'),
#                 ('tx_token', ''),
#                 ('weight', '33.0'),
#                 ('type', 'directed'),
#                 ('token_name', 'Sarafu'),
#                 ('token_address',
#                  '0x0Fd6e8F2320C90e9D4b3A5bd888c4D556d20AbD4')])},
#   {'2020-08-12': OrderedDict([('', '357792'),
#                 ('id', '453050'),
#                 ('timeset', '2020-08-12'),
#                 ('transfer_subtype', 'AGENT_OUT'),
#                 ('transfer_use', ''),
#                 ('source', '0x13fA16d31F16949D28eD7984b82f7e0Bd5757b78'),
#                 ('s_comm_tkn', 'None'),
#                 ('s_gender', 'female'),
#                 ('s_location_path', 'Mukuru Kayaba Village,Makongeni,Nairobi'),
#                 ('s_location_lat', '36.84450844411661'),
#                 ('s_location_lon', '-1.3112602'),
#                 ('s_business_type', 'Savings Group'),
#                 ('target', '0x245fc81fe385450Dc0f4787668e47c903C00b0A1'),
#                 ('t_comm_tkn', 'None'),
#                 ('t_gender', 'female'),
#                 ('t_location_path', 'Kilifi,Kilifi,Coastal Kenya'),
#                 ('t_location_lat', '39.85'),
#                 ('t_location_lon', '-3.6333'),
#                 ('t_business_type', 'Savings Group'),
#                 ('tx_token', ''),
#                 ('weight', '2000.0'),
#                 ('type', 'directed'),
#                 ('token_name', 'Sarafu'),
#                 ('token_address',
#                  '0x0Fd6e8F2320C90e9D4b3A5bd888c4D556d20AbD4')])},
#   {'2020-10-19': OrderedDict([('', '472460'),
#                 ('id', '569906'),
#                 ('timeset', '2020-10-19'),
#                 ('transfer_subtype', 'RECLAMATION'),
#                 ('transfer_use', ''),
#                 ('source', '0x245fc81fe385450Dc0f4787668e47c903C00b0A1'),
#                 ('s_comm_tkn', 'None'),
#                 ('s_gender', 'female'),
#                 ('s_location_path', 'Kilifi,Kilifi,Coastal Kenya'),
#                 ('s_location_lat', '39.85'),
#                 ('s_location_lon', '-3.6333'),
#                 ('s_business_type', 'Savings Group'),
#                 ('target', '0xEDA5C9B75Fdb3B9bdAB987A704632280Cf93084F'),
#                 ('t_comm_tkn', 'None'),
#                 ('t_gender', 'system'),
#                 ('t_location_path', 'None'),
#                 ('t_location_lat', 'None'),
#                 ('t_location_lon', 'None'),
#                 ('t_business_type', 'System'),
#                 ('tx_token', ''),
#                 ('weight', '160.0'),
#                 ('type', 'directed'),
#                 ('token_name', 'Sarafu'),
#                 ('token_address',
#                  '0x0Fd6e8F2320C90e9D4b3A5bd888c4D556d20AbD4')])},
#   {'2020-11-02': OrderedDict([('', '508633'),
#                 ('id', '606450'),
#                 ('timeset', '2020-11-02'),
#                 ('transfer_subtype', 'RECLAMATION'),
#                 ('transfer_use', ''),
#                 ('source', '0x245fc81fe385450Dc0f4787668e47c903C00b0A1'),
#                 ('s_comm_tkn', 'None'),
#                 ('s_gender', 'female'),
#                 ('s_location_path', 'Kilifi,Kilifi,Coastal Kenya'),
#                 ('s_location_lat', '39.85'),
#                 ('s_location_lon', '-3.6333'),
#                 ('s_business_type', 'Savings Group'),
#                 ('target', '0xEDA5C9B75Fdb3B9bdAB987A704632280Cf93084F'),
#                 ('t_comm_tkn', 'None'),
#                 ('t_gender', 'system'),
#                 ('t_location_path', 'None'),
#                 ('t_location_lat', 'None'),
#                 ('t_location_lon', 'None'),
#                 ('t_business_type', 'System'),
#                 ('tx_token', ''),
#                 ('weight', '9.0'),
#                 ('type', 'directed'),
#                 ('token_name', 'Sarafu'),
#                 ('token_address',
#                  '0x0Fd6e8F2320C90e9D4b3A5bd888c4D556d20AbD4')])}]}

# %% [markdown]
# ### Update userData by time step

# %%
userData = userData_dict
txnData = txnData_dict
#userData = dict(itertools.islice(userData_dict.items(), 30))  
#txnData = dict(itertools.islice(txnData_dict.items(), 30))  

headersUserPub = ['id', 'start', 'label', 'gender', 'location', 'lat','lon', 
              'held_roles', 'business_type', 'bal', 'xDAI_blockchain_address', 
              'ovol_in', 'ovol_out', 'otxns_in', 'otxns_out', 'ounique_in', 'ounique_out', 
              'svol_in', 'svol_out', 'stxns_in', 'stxns_out', 'sunique_in', 'sunique_out',
              'sunique_out_group', 'sunique_in_at', 'sunique_out_at', 'sunique_out_at_group',
              'days_enrolled', 'days_active', 'trades_in_daily', 'trades_out_daily', 
              'trade_partners_in_daily', 'trade_partners_out_daily', 'gender_ratio_in', 'gender_ratio_out']

# Restriction matrix to be used in Propensity Score Matching
# headersUserPub.extend(list(userData.keys()))

# %%
def create_userData(userData, txnData, start_date, end_date, headersUserPub):

    for user in userData.keys():
        volume_in = 0
        volume_out = 0
        txns_in = 0 # all trades
        txns_out = 0
        unique_txns_in = 0 # unique trades
        unique_txns_out = 0

        svolume_in = 0
        svolume_out = 0
        stxns_out = 0
        stxns_in = 0
        sunique_txns_out = 0
        sunique_txns_out_group = 0
        sunique_txns_in = 0

        sunique_txns_out_atleast = 0
        stotal_unique_txns_out_atleast = 0
        stotal_unique_txns_out_atleast_group = 0
        #stotal_unique_txns_out_atleast_group += 1
        sunique_txns_out_atleast_group = 0
        sunique_txns_in_atleast = 0
        
        females_sold_to = 0
        males_sold_to = 0
        females_bought_from = 0
        males_bought_from = 0

        min_size = 5 # min Sarafu trade amount (?)

        sseenRecUsers = [] # user's recipients ("people who've bought from me")
        seenRecUsers = []

        sseenSentUsers = [] # recipient user's partner ("people I've bought from")
        seenSentUsers = []
        
        # Initialize at zero interactions between all users
        #ids = [i for i in uD.xDAI_blockchain_address]
        #ids = list(userData.keys())
        #interaction_dict = dict(zip(ids, [0 for i in range(len(ids))]))

        if(user in txnData.keys()): # if user has participated in a trade in the txnData dict
            txns = txnData[user] # list containing dicts for each txn
            #for trans in txnData[user]: # for each txn in the user's txn array
            for txn in txns: # parses each txn dict, where the key is the date
                date_str = list(txn.keys())[0]
                date = datetime.strptime(date_str, '%Y-%m-%d')
                if start_date <= date <= end_date: # checks that the date is within the defined range
                    trans = txn[date_str]
                    #for trans in txn:
                    if trans['source'] == user:
                        if trans['transfer_subtype'] != 'STANDARD':
                            volume_out+=float(trans['weight'])
                            txns_out+=1
                            if trans['target'] not in seenRecUsers:
                                seenRecUsers.append(trans['target'])
                                unique_txns_out+=1

                        else: # standard txn with other users
                            svolume_out+=float(trans['weight'])
                            stxns_out+=1
                            
                            if userData[trans['target']]['gender'] == 'female':
                                females_sold_to+=1
                            elif userData[trans['target']]['gender'] == 'male':
                                males_sold_to+=1
                            
                            #if (user == 4082):
                            #    print(stxns_out)
                            if trans['target'] not in sseenRecUsers: # txn is standard and unqiue
                                sseenRecUsers.append(trans['target'])
                                sunique_txns_out+=1
                                if userData[user]['held_roles'] == "GROUP_ACCOUNT":
                                    sunique_txns_out_group += 1
                                if(float(trans['weight'])>=min_size):
                                    sunique_txns_out_atleast += 1
                                    if sunique_txns_out_atleast > 1:
                                        stotal_unique_txns_out_atleast += 1
                                    if userData[user]['held_roles'] == "GROUP_ACCOUNT":
                                        sunique_txns_out_atleast_group += 1
                                        if sunique_txns_out_atleast_group > 1:
                                            stotal_unique_txns_out_atleast_group += 1


                    else: # this txn marks where the user was a recipient
                        if trans['transfer_subtype'] != 'STANDARD':
                            #if user == 13488:
                            #    print("<><><><> ",trans['_transfer_amount_wei'], trans['created'])
                            volume_in+=float(trans['weight'])
                            txns_in+=1
                            
                            if userData[trans['source']]['gender'] == 'female':
                                females_bought_from+=1
                            elif userData[trans['source']]['gender'] == 'male':
                                males_bought_from+=1
                            
                            if trans['source'] not in seenSentUsers:
                                seenSentUsers.append(trans['source'])
                                unique_txns_in+=1
                            
                        else:
                            svolume_in+=float(trans['weight'])
                            stxns_in+=1
                            if trans['source'] not in sseenSentUsers:
                                sseenSentUsers.append(trans['source'])
                                sunique_txns_in+=1
                                if(float(trans['weight'])>=min_size):
                                    sunique_txns_in_atleast+=1

                                    
            # kinda bad practice: using individual txn keys, which are dates, to parse first and last txn
            # NB first txn is NOT 0-indexed because this would be their disbursement i.e registration txn
            # – this doesn't count as "active trading"
            
            if len(txnData[user]) == 1: 
                first_trade_date = datetime.strptime(list(txnData[user][0].keys())[0], '%Y-%m-%d') 
            elif len(txnData[user]) > 1:
                first_trade_date = datetime.strptime(list(txnData[user][1].keys())[0], '%Y-%m-%d') 
            last_trade_date = datetime.strptime(list(txnData[user][-1].keys())[0], '%Y-%m-%d')
            #start = datetime.strptime(userData[user]['start'].to_string(index=False), '%Y-%m-%d')
            start = datetime.strptime(userData[user]['start'], '%Y-%m-%d')
            end = end_date

            days_enrolled = (end - start).days
            days_active = abs(last_trade_date - first_trade_date).days
            
            # Avoid division by zero:
            if days_enrolled == 0:
                days_enrolled = 1
            if days_active == 0:
                days_active = 1

            trades_in_daily = stxns_in/days_active
            trades_out_daily = stxns_out/days_active
            trade_partners_in_daily = sunique_txns_in/days_active
            trade_partners_out_daily = sunique_txns_out/days_active
            
            # Avoid division by zero:
            if males_sold_to == 0:
                males_sold_to = 1
            if males_bought_from == 0:
                males_bought_from = 1
                
            gender_ratio_out = females_sold_to/males_sold_to
            gender_ratio_in = females_bought_from/males_bought_from
            #total_unique_out_atleast += stotal_unique_txns_out_atleast
            
            # Populate the restriction matrix
            
            """
            seen = sseenRecUsers
            seen.extend(x for x in sseenSentUsers if x not in seen)
            for trade_partner in seen:
                interaction_dict[trade_partner] = 1
            
            interacted = list(interaction_dict.values())
            """

                
        """
                
        data = [volume_in, volume_out, txns_in, txns_out, unique_txns_in, unique_txns_out, svolume_in, 
                svolume_out, stxns_in, stxns_out, sunique_txns_in, sunique_txns_out, sunique_txns_out_group, 
                sunique_txns_in_atleast, sunique_txns_out_atleast, sunique_txns_out_atleast_group, 
                days_enrolled, days_active, trades_in_daily, trades_out_daily, trade_partners_in_daily, 
                trade_partners_out_daily, gender_ratio_in, gender_ratio_out]
        """

        #data.extend(interacted)
        
        #txData = {headersUserPub[i]: data[i] for i in range(len(headersUserPub[11:]))}
        
        txData = {'ovol_in': volume_in, 
          'ovol_out':volume_out, 
          'otxns_in': txns_in, 
          'otxns_out': txns_out,
          'ounique_in': unique_txns_in, 
          'ounique_out': unique_txns_out, 
          'svol_in': svolume_in, 
          'svol_out': svolume_out, 
          'stxns_in':stxns_in, 
          'stxns_out': stxns_out, 
          'sunique_in': sunique_txns_in, 
          'sunique_out': sunique_txns_out,
          'sunique_out_group': sunique_txns_out_group, 
          'sunique_in_at': sunique_txns_in_atleast,
          'sunique_out_at': sunique_txns_out_atleast, 
          'sunique_out_at_group': sunique_txns_out_atleast_group,
          'days_enrolled': days_enrolled, 
          'days_active': days_active, 
          'trades_in_daily': trades_in_daily, 
          'trades_out_daily': trades_out_daily, 
          'trade_partners_in_daily': trade_partners_in_daily, 
          'trade_partners_out_daily': trade_partners_out_daily,
          'gender_ratio_in': gender_ratio_in,
          'gender_ratio_out': gender_ratio_out}

        uDict = userData[user]
        uDict.update(txData)
        userData[user] = uDict

# %%
# This cell takes approx. 10 min to run!
create_userData(userData, txnData, start_date, end_date, headersUserPub)

# %%
def generate_user_and_transaction_data_github_csv(txnData, userData, unique_txnData, start_date, end_date, days_ago_str, headersUserPub, private=False):

    headersTxPub = ['id', 'timeset', 'transfer_subtype', 'transfer_use','source', 's_comm_tkn', 's_gender', 's_location_path', 's_location_lat','s_location_lon',
                     's_business_type', 'target', 't_comm_tkn', 't_gender',
                    't_location_path', 't_location_lat', 't_location_lon',
                     't_business_type', 'tx_token', 'weight', 'type','token_name', 'token_address']

    headersUser = headersUserPub
    headersTx = headersTxPub
    
    #filenameTx = '/Users/rebeccamqamelo/Desktop/Capstone/tx_all_pub_'+start_date.strftime("%Y-%m-%d")+"-"+end_date.strftime("%Y-%m-%d")+"-"+days_ago_str+'.csv'
    #filenameUser = '/Users/rebeccamqamelo/Desktop/Capstone/users_all_pub_'+start_date.strftime("%Y-%m-%d")+"-"+end_date.strftime("%Y-%m-%d")+"-"+days_ago_str+'.csv'
    filenameTx = '/Users/rebeccamqamelo/Desktop/Capstone/txnData_all_time.csv'
    filenameUser = '/Users/rebeccamqamelo/Desktop/Capstone/userData_all_time.csv'
    
    print("saving all transactions to: ", filenameTx)
    print("saving all users to: ", filenameUser)

    #timestr = time.strftime("%Y%m%d-%H%M%S")
    timestr = time.strftime("%Y-%m-%d")

    token_transactions = txnData

    indexR = 0

    seen_users = []
    exclude_list = []

    if True:
        numberTx = 1
        numberUsers = 0

        with open(filenameTx, 'w', newline='') as csvfileTx, open(filenameUser, 'w', newline='') as csvfileUser:
            #spamwriterTx = csv.writer(csvfileTx)
            #spamwriterTx.writerow(headersTx)

            spamwriterUser = csv.writer(csvfileUser)
            spamwriterUser.writerow(headersUser)

            for user_id, user_info in userData.items():

                user_data1 = {'start': user_info['start']}
                user_data1['id'] = user_info['id']
                user_data1['label'] = user_info['id']
                user_data1['xDAI_blockchain_address'] = user_id
                #user_data1['xDAI_blockchain_address'] = user_info['xDAI_blockchain_address']

                #user_data1['comm_tkn'] = user_info['comm_tkn']

                user_data1['bal'] = user_info['bal']
                user_data1['gender'] = user_info.get('gender')
                user_data1['location'] = user_info.get('location')
                user_data1['lat'] = user_info.get('lat')
                user_data1['lon'] = user_info.get('lon')
                user_data1['held_roles'] = user_info['held_roles']
                user_data1['business_type'] = user_info['business_type']
                user_data1['ovol_in'] = user_info['ovol_in']
                user_data1['ovol_out'] = user_info['ovol_out']
                user_data1['otxns_in'] = user_info['otxns_in']
                user_data1['otxns_out'] = user_info['otxns_out']
                user_data1['ounique_in'] = user_info['ounique_in']
                user_data1['ounique_out'] = user_info['ounique_out']
                user_data1['svol_in'] = user_info['svol_in']
                user_data1['svol_out'] = user_info['svol_out']
                user_data1['stxns_in'] = user_info['stxns_in']
                user_data1['stxns_out'] = user_info['stxns_out']
                user_data1['sunique_in'] = user_info['sunique_in']
                user_data1['sunique_out'] = user_info['sunique_out']
                user_data1['sunique_out_group'] = user_info['sunique_out_group']
                user_data1['sunique_in_at'] = user_info['sunique_in_at']
                user_data1['sunique_out_at'] = user_info['sunique_out_at']
                user_data1['sunique_out_at_group'] = user_info['sunique_out_at_group']
                user_data1['days_enrolled'] = user_info['days_enrolled']
                user_data1['days_active'] = user_info['days_active']
                user_data1['trades_in_daily'] = user_info['trades_in_daily']
                user_data1['trades_out_daily'] = user_info['trades_out_daily']
                user_data1['trade_partners_in_daily'] = user_info['trade_partners_in_daily']
                user_data1['trade_partners_out_daily'] = user_info['trade_partners_out_daily']
                user_data1['gender_ratio_in'] = user_info['gender_ratio_in']
                user_data1['gender_ratio_out'] = user_info['gender_ratio_out']
                #user_data1['confidence'] = user_info['confidence']
                
                
                #user_data1 = {headersUserPub[i]: user_info[i] for i in range(len(headersUserPub))}
                numberUsers+=1
                spamwriterUser.writerow([str(user_data1[k]) for k in headersUser])

            c_idx = 0
            chunks = 10000
            tx_hash = []

            """
            #for tnsfer_acct__id, transactions in txnData.items():
            if len(unique_txnData) > 0:
                for key, t in unique_txnData.items():
                #for t in unique_txnData:
                    #if t['id'] in tx_hash:  # only looking at unique data: note that without this there will be double counting on transactions
                    #    print("Error: duplicate transaction found!", t['id'])
                    #    time.sleep(1.5)
                    #    continue
                    #tx_hash.append(t['id'])

                    sender_user_id = t['source']
                    print(sender_user_id)
                    recipient_user_id = t['target']
                    print(recipient_user_id)

                    if sender_user_id == None:
                        sender_user_id = 1
                    #elif sender_user_id == '0xEDA5C9B75Fdb3B9bdAB987A704632280Cf93084F': # Grassroots Economics System
                        #sender_user_id = 1

                    if recipient_user_id == None:
                        recipient_user_id = 1

                    row_data = {'timeset': t['timeset']}

                    row_data['weight'] = t['weight']
                    row_data['type'] = 'directed'
                    row_data['transfer_subtype'] = t['transfer_subtype']
                    row_data['id'] = t['id']
                    #row_data['label'] = t['label']
                    #if private:
                        #row_data['tx_hash'] = t['tx_hash']
                    row_data['token_name'] = t['token_name']
                    row_data['authorising_user_id'] = t.get('authorising_user_id') #t['authorising_user_id']
                    row_data['token_address'] = t['token_address']
                    
                    #if t['transfer_use'] != None:
                        #row_data['transfer_use'] = t['transfer_use'][0].strip('"[]')
                    #else:
                        #row_data['transfer_use'] = ''
                    row_data['transfer_use'] = t['transfer_use']

                    #row_data['source'] = userData[sender_user_id]['blockchain_address']
                    row_data['source'] = userData[sender_user_id]['xDAI_blockchain_address']
                    row_data['s_location_path'] = userData[sender_user_id].get('s_location_path')
                    row_data['s_location_lat'] = userData[sender_user_id].get('s_location_lat')
                    row_data['s_location_lon'] = userData[sender_user_id].get('s_location_lon')
                    row_data['t_location_path'] = userData[recipient_user_id].get('t_location_path')
                    row_data['t_location_lat'] = userData[recipient_user_id].get('t_location_lat')
                    row_data['t_location_lon'] = userData[recipient_user_id].get('t_location_lon')
                    row_data['s_gender'] = userData[sender_user_id].get('s_gender')
                    row_data['s_comm_tkn'] = userData[sender_user_id]['s_comm_tkn']
                    row_data['s_business_type'] = userData[sender_user_id]['s_business_type']

                    row_data['target'] = userData[recipient_user_id]['target']
                    if True:
                        row_data['t_gender'] = userData[recipient_user_id].get('gender')
                        row_data['t_comm_tkn'] = userData[recipient_user_id]['t_comm_tkn']
                        row_data['t_business_type'] = userData[recipient_user_id]['t_business_type']

                    if True: #Admin ONLY row_data['authorising_user_id'] is not None and row_data['authorising_user_id'] != 6: #Admin ONLY
                        rowString = []
                        for k in headersTx:
                            if k in row_data.keys():
                                #spamwriterTx.writerow([str(row_data[k]) for k in headersTx])
                                rowString.append(str(row_data[k]))
                            else:
                                rowString.append('')

                        spamwriterTx.writerow(rowString)
                        if indexR < 3:
                            #print(row_data) #debug
                            indexR+=1
                        if c_idx >= chunks:
                            c_idx = 0
                            csvfileTx.flush()  # whenever you want
                            print("chunk: ", numberTx)
                        else:
                            c_idx += 1

                        numberTx += 1

        print("****saved all transactions to csv", filenameTx, " number of tx:", numberTx, timestr)
            
            """   
        print("****saved all users to csv", filenameUser, " number of User:", numberUsers, timestr)

# %%
unique_txnData = txnData.copy()
days_ago_str = "all_time"
generate_user_and_transaction_data_github_csv(txnData, userData, unique_txnData, start_date, end_date, days_ago_str, headersUserPub, private=False)
# Out:
# saving all transactions to:  /Users/rebeccamqamelo/Desktop/Capstone/txnData_all_time.csv
# saving all users to:  /Users/rebeccamqamelo/Desktop/Capstone/userData_all_time.csv
# ****saved all users to csv /Users/rebeccamqamelo/Desktop/Capstone/userData_all_time.csv  number of User: 40941 2020-11-17
